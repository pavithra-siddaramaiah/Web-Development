# %%
Javascript

# %% [markdown]
# Javascript is a scripting langauage
# Javascript is no where related to java, its just like comparing car and carpet
#
# Its like a script in cinema
# Javascript is an interepreted languagae (=>Means easily understandable language. User interpreted), other examples are python, ruby
#
# java is a compiled programming language=> complex instruction, not easily understandable. other examples are C/C++

# %% [markdown]
# To open a console in a browser
# Open a new page in browser, then go to view->developer->java script console.
# If we type something over there-> it will be displayed on the webpage
# Ex: alert("Hello"); =>as soon as we click enter, this alert message will be popped up on the screen
#
# Suppose now if we want to write more lines of code. Then click on shift+enter rather than just enter
# Anothe rway to solve this problem is by opening the snippet. This can be done by Sources(option next to console) then selecting the snippet form the arrow. When can write our code there and can be executed everything at once.
#
# here alert is a function/keyword
# Double or single coutes can be used
# Semicolon is mandatory-> to indicate the browser that its an end of line
#
# For more details visit mdn docs. Also have a loon on https://github.com/rwaldron/idiomatic.js for more details understanding how to write the code. Neat and organized way

# %% [markdown]
# Data types and variables in js
#
# There are various data types in js like string, numbers, boolean, etc.
#
# Var is like a container, var name is like a name of the container, var value is teh content inside the container. see the image below for more understanding
# ![image.png](attachment:image.png)
#
# Only during the time of initializing the variable name we use var keyword, later on we just access the variable by its name
# var myName "pavithra" ;
# myName = "jane" ;
#
# Values of variables can also be changed.
#
# prompt is a keyword used to diaplay a prompt on the screen.
# var yourName = prompt("Enter your name");
# alert("Your name is:" + yourName);
#
# Command+K used to clear the console in js, data will not be removed
# if you want to delet the data completely then hover the mouse near refresh button->empty cache and hard reload.

# %% [markdown]
# Variable names
# -should follow camel case-> myName, myFatherName,...first should should be small
# -no space allows. Inly alphabets, numbers, $, and _ are allowed in var names
# -should be readable, understandable, it should make sense if another person reads it

# %% [markdown]
# String concatenation and counting characters.
# To find the number of characters we can used .length;
# var count;
# count = prompt("Enter your openion")
# alert("You have written "+ (count.length) +" characters."+" You have "+(240-(count.length))+ " characters left");
# -----------------------------------------------------------------------------------------------------------------
# To slice the paragraph or limit the content to certain value => .slice(x,y) has been used.
# var count = prompt("Enter your text:")
# var totalCount = count.length;
# var tweetCountUnder50 = count.slice(0,50);
# alert(tweetCountUnder50)
# -----------------------------------------------------------------------------------------------------------------
# uppercase and Lowercase
# var name = prompt("Enter your name:")
# name = name.toUpperCase();
# name = name.toLowerCase();
#
# Airthmetic Operatos:
# Addition: var a = 4+2; //6
# Subtraction: var a =  4-2; //2
# Multiplication: var a = 4*2; //8
# Division: var a = 4/2; //2
# Modulus: var a = 4%2; //0
# When we have multiple operators in the equation make use of precedence;
#
# Increment and Decrement Expressions:
# var x = 5;
# x++; //6
# x--;//5
#
# Important!!
# var x = 5;
# var y = x++;
# y+ = 1; //5. This is because in the previous step y will take the value of 5 not 6. X++ shoud be incremented first and then it should be used to have the proper value. If not if used in the same equation, it assign the previous value before x++;

# %% [markdown]
# Functions
#
# Mainly reduce the repeativity in the code.
# format is as shown below:
# function putBeeperDiagonally(){
#     //place the code here.
# }
# In order to call the function use putBeeperDiagonally();
# Suppose we have robot and we write the instruction to getMilk, instead of using the alert command use console.log, so that logs can be seen in the console and we don't get the popup oftenly.
#
# parameters and arguments:
# we can pass a parameter to a function as shown below:
#
# function getMilk(bottles){
#     ....used bottles variables inside the function....
# }
# getMilk(5);
#
# Outputs and return values:
# function getMilk(money){
#     return money%1.5;
# }
# that returned value must be stored to some variable..
# var change = getMilk(4);
# console.log(change);
#
# Math.floor() can be used to roundof the values
# Math.pow(base, exponenet);
# Math.round();
# ![image.png](attachment:image.png)
# getMilk(5);

# %% [markdown]
# In order to generate a random number Math.random(); function is used.
# this random function gives the value between 0 and 0.9999999999(upto 16 decimal digits)
# prompt("Enter you name");
# prompt("Enter your partner name")
# var num = Math.random();
# var num1 = num * 100; //inorder to genenarate the number between [1 to 100]
# var num2 = Math.floor(num1)+1;[we don't want 0]
# alert("Your love percentage is : "+num2);
#
# Conditional statements
# =======================
# if(num2 > 70){
#     alert(",..");
# }
# else {
#     alert("...");
# }
#
# === is equal to, check content along with data type
# == just checking the content which are equal or not
# !== not equal to
# > greater
# < lesser
# >= greater or equal to
# <= lesser or equal to
#
# Combining Comparators:
# ======================
# && AND
# || OR
# ! NOT
# ex: if(a>=b && a<=4 ){
#     console.log("..");
# }

# %% [markdown]
# Array
#
# an array is the collection of items that are related can be stored in ths same container
# var alpha = [a,b,c,d,e,f]
# alpha.length; //6
#
# var namesList = ["anu", "banu", "manu", "canu"];
# var checkName = prompt("Enter you name");
#
# if(namesList.includes(checkName)){
#     alert("Wecome!");
# }
# else{
#     alert("May be next time!");
# }
#
# array.includes() function ======> important
# .push(); ==> adds the elements to the array, it always adds to last;
# .pop; ==> removes the last element from the array
#
#
# var output = [];
# var count = 1;
#
# function createArray(){
#
#
#     if(count%3 === 0){
#         output.push("Fizz");
#
#     }
#
#     else if(count%5 === 0){
#         output.push("Buzz");
#
#     }
#
#     else if((count%3 === 0) && (count%5 === 0)){
#         output.push("FizzBuzz");
#
#     }
#     else {
#         output.push(count);
#     }
#     count++;
#
#     console.log(output);
# }

# %% [markdown]
# Loops
#
# while loop
#
# while(something is true){
#     do .......
# }
#
# for loop
# for(var i=0; i<2; i++){
#     ......
# }

# %% [markdown]
# What does methods return:
#
# .push() => returns the current length of the array
# .pop() => returns the item(last element in the array) that is removed
# The .unshift() method of an array allows you to add a value to the beginning of the array, unlike .push() which adds the value at the end of the array.
# Arrays also have a .shift() method. This will remove the first element of the array, unlike .pop() which removes the last element. Here is an example of the .shift() method:
#
# Up until now, any time text.innerText was updated, the old text was erased. This time, use the += operator to add text to the end of text.innerText.
#
# The .includes() method determines if an array contains an element and will return either true or false.

# %% [markdown]
# const character = "#";
# const count = 8;
# const rows = [];
# let inverted = true;
# function padRow(rowNumber, rowCount) {
#   return " ".repeat(rowCount - rowNumber) + character.repeat(2 * rowNumber - 1) + " ".repeat(rowCount - rowNumber);
# }
#
# for (let i = 1; i <= count; i++) {
#   if (inverted) {
#     rows.unshift(padRow(i, count));
#   } else {
#     rows.push(padRow(i, count));
#   }
# }
#
# let result = ""
#
# for (const row of rows) {
#   result = result + "\n" + row;
# }
#
# console.log(result);

# %% [markdown]
# function getAverage(scores) {
#   let sum = 0;
#
#   for (const score of scores) {
#     sum += score;
#   }
#
#   return sum / scores.length;
# }
#
# function getGrade(score) {
#   if (score === 100) {
#     return "A++";
#   } else if (score >= 90) {
#     return "A";
#   } else if (score >= 80) {
#     return "B";
#   } else if (score >= 70) {
#     return "C";
#   } else if (score >= 60) {
#     return "D";
#   } else {
#     return "F";
#   }
# }
#
# function hasPassingGrade(score) {
#   return getGrade(score) !== "F";
# }
#
# function studentMsg(totalScores, studentScore) {
#   let classAverage = getAverage(totalScores);
#   let yourGrade = getGrade(studentScore);
# if (yourGrade === "F"){
#   return ("Class average: "+classAverage+". Your grade: "+yourGrade+". You failed the course.")
# }
# else {
#   return ("Class average: "+classAverage+". Your grade: "+yourGrade+". You passed the course.")
# }
#
# }
# console.log(studentMsg([92, 88, 12, 77, 57, 100, 67, 38, 97, 89], 37));
