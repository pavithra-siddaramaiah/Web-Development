# %% [markdown]
# DATABASE
#
# Minly 2 types: SQL and NoSQL
#
# SQL => structured query language
# Also called relational database because its easy to connect two tables.
# Ex: MySQL, PostgreSQL, Oracle, SQLLite, etc
# ![image.png](attachment:image.png)
#
# NoSQL: its more like a json means we can store teh data in our own way. not structured like SQL
# ![image-2.png](attachment:image-2.png)
# ex: Redis, Mangodb, dynamo

# %% [markdown]
# In SQL data stored in the form of a table. Each entry is called Row/Record. Consists of columns
# , where in no SQL data sroted in the form of collection [collection of objects]. Like we  have Rew in sql here we have document and column=field
# [
#     {
#         "id" : "13f",
#         "name": "fsfgg"
#     }, {}
# ]

# %% [markdown]
# we use different drivers inorder to integrate mongodb with respective programming languages
#
# as of now we use the shell and then will check how to use drivers

# %% [markdown]
# Drivers are the libraries that allow you to interact with the mongodb database from a wide range of programming languages
# Since we are using the node.js in our application we will be using node drivers
# https://www.mongodb.com/docs/drivers/node/current/

# %% [markdown]
# mongod --dbpath /Users/pavithrasiddaramaiah/mongodb/data --logpath /Users/pavithrasiddaramaiah/mongodb/logs/mongo.log
#
# this is the command used to start the serverb
#
# in another terminal window we run command: mongosh to start the mongodb shell
# use shop
# to add an item we do =>
# db.products.insertOne({name: "ps", age: 25})
# here products is the collections
# {} => document

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# drivers will communicate with teh mongodb server, further mongodb communicates with the storage engine to do the requested operations.
#
# storage engine actually make use of teh memory to make things faster than the local storage

# %% [markdown]
# tail -n 100 /Users/pavithrasiddaramaiah/mongodb/logs/mongo.log
#
#
# {"t":{"$date":"2024-07-17T14:46:40.145-04:00"},"s":"I",  "c":"CONTROL",  "id":4615611, "ctx":"initandlisten","msg":"MongoDB starting","attr":{"pid":59734,"port":27017,"dbPath":"/Users/pavithrasiddaramaiah/mongodb/data","architecture":"64-bit","host":"Pavithras-Air"}} => with this log we can say on  which port server is running

# %% [markdown]
# Now lets add some data to the database
#
# use flights //create a database with name flights
# the we can add the json data into it and look for it as shown below:
# test> use flights
# switched to db flights
# flights> db.flightData.insertOne({
# ...     "departureAirport": "MUC",
# ...     "arrivalAirport": "SFO",
# ...     "aircraft": "Airbus A380",
# ...     "distance": 12000,
# ...     "intercontinental": true
# ...   })
# {
#   acknowledged: true,
#   insertedId: ObjectId('669819cc437d9b12c9881fb5')
# }
# flights> db.flightData.find()
# [
#   {
#     _id: ObjectId('669819cc437d9b12c9881fb5'),
#     departureAirport: 'MUC',
#     arrivalAirport: 'SFO',
#     aircraft: 'Airbus A380',
#     distance: 12000,
#     intercontinental: true
#   }
# ]
# flights>
